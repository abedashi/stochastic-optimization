# %%
import os
import time
import subprocess
import pandas as pd
import matplotlib.pyplot as plt

from algorithms.utils import read_input, write_solution
from algorithms.tabu_search import tabu_search, calculate_cost

# %%
# Paths
input_file = "data/instances/i02.json"
output_file = "data/output_solutions/out_sol_test02.json"
log_file = "./performance_log.csv"

# Ensure output folder exists
os.makedirs("./data/output_solutions", exist_ok=True)

# Initialize performance log
performance_log = []

# Step 1: Load Input Data
print(f"Processing {input_file}...")
data = read_input(input_file)

# Step 2: Run Tabu Search
start_time = time.time()
best_solution, cost_history = tabu_search(data, iterations=20, tabu_tenure=10)
end_time = time.time()

# Step 3: Calculate Final Cost
final_cost = calculate_cost(best_solution, data)

# Step 4: Save Solution
write_solution(output_file, best_solution)

# Step 5: Log Performance
performance_log.append({
    "instance": os.path.basename(input_file),
    "final_cost": final_cost,
    "execution_time": round(end_time - start_time, 2)
})

# Save log to CSV
df_log = pd.DataFrame(performance_log)
if os.path.exists(log_file):
    df_log.to_csv(log_file, mode='a', index=False, header=False)
else:
    df_log.to_csv(log_file, index=False, header=True)

print(f"Completed {input_file}: Cost = {final_cost}, Time = {round(end_time - start_time, 2)}s")
print(f"Solution saved to: {output_file}\n")

# Step 6: Run Validator Command
print("Running Validator...")
violations = {}
costs = {}
try:
    result = subprocess.run(
        ["./IHTP_Validator", input_file, output_file, "verbose"],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        check=True
    )
    print("Validator Output:")
    print(result.stdout)

    # Parse violations from validator output
    parsing_costs = False  # Track whether we are parsing the COSTS section
    for line in result.stdout.splitlines():
        if "VIOLATIONS:" in line:
            continue  # Skip the heading for violations
        if "COSTS" in line:
            parsing_costs = True  # Start parsing costs
            continue
        if "Total violations" in line or "Total cost" in line:
            continue  # Skip total lines
        if "...." in line and not parsing_costs:  # Parse violations
            parts = line.split("....", maxsplit=1)  # Split at the first set of dots
            if len(parts) == 2:
                key = parts[0].strip()  # Extract the violation name
                value_part = parts[1].strip()  # Extract the value part
                try:
                    # Extract only digits from the value
                    value = int(''.join(filter(str.isdigit, value_part)))
                    violations[key] = value
                except ValueError:
                    print(f"Warning: Could not parse value for {key} -> {value_part}")
        elif parsing_costs and "..." in line:  # Parse costs
            parts = line.split("...", maxsplit=1)  # Split at the first set of dots
            if len(parts) == 2:
                key = parts[0].strip()  # Extract the cost name
                value_part = parts[1].strip()  # Extract the value part
                try:
                    # Extract only digits from the value
                    value = int(''.join(filter(str.isdigit, value_part.split("(")[0])))
                    costs[key] = value
                except ValueError:
                    print(f"Warning: Could not parse value for {key} -> {value_part}")


except subprocess.CalledProcessError as e:
    print("Error running validator:")
    print(e.stderr)
# Out:
# Processing data/instances/i02.json...
# Iteration 0: Cost = 4237900
# Iteration 1: Cost = 3633966
# Iteration 2: Cost = 3034014
# Iteration 3: Cost = 2434135
# Iteration 4: Cost = 1835152
# Iteration 5: Cost = 1383144
# Iteration 6: Cost = 931166
# Iteration 7: Cost = 628193
# Iteration 8: Cost = 326179
# Iteration 9: Cost = 25096
# Iteration 10: Cost = 22112
# Iteration 11: Cost = 20118
# Iteration 12: Cost = 18174
# Iteration 13: Cost = 16214
# Iteration 14: Cost = 15167
# Iteration 15: Cost = 14124
# Iteration 16: Cost = 13101
# Iteration 17: Cost = 12104
# Iteration 18: Cost = 11139
# Iteration 19: Cost = 9188
# Completed data/instances/i02.json: Cost = 9188, Time = 116.13s
# Solution saved to: data/output_solutions/out_sol_test02.json
#
# Running Validator...
# Validator Output:
# Room r0 is gender-mixed 2/1 on day 2
# Room r0 is gender-mixed 2/1 on day 3
# Room r0 is gender-mixed 1/2 on day 11
# Room r0 is gender-mixed 1/1 on day 12
# Room r0 is gender-mixed 1/2 on day 13
# Room r2 is gender-mixed 1/1 on day 1
# Room r2 is gender-mixed 1/2 on day 2
# Room r2 is gender-mixed 3/1 on day 3
# Room r2 is incompatible with patient p13
# Room r2 is incompatible with patient p20
# Room r0 is incompatible with patient p26
# Room r3 is incompatible with patient p27
# Room r1 is overloaded by 2 on day 1
# Room r1 is overloaded by 2 on day 2
# Room r1 is overloaded by 2 on day 3
# Room r1 is overloaded by 2 on day 4
# Room r1 is overloaded by 2 on day 5
# Room r1 is overloaded by 1 on day 6
# Room r1 is overloaded by 1 on day 7
# Room r0 is uncovered in shift 28 (day9@late)
# Room r0 is uncovered in shift 35 (day11@night)
# Room r0 is uncovered in shift 40 (day13@late)
# Room r1 is uncovered in shift 14 (day4@night)
# Room r1 is uncovered in shift 25 (day8@late)
# Room r1 is uncovered in shift 41 (day13@night)
# Room r2 is uncovered in shift 0 (day0@early)
# Room r2 is uncovered in shift 35 (day11@night)
# Room r3 is uncovered in shift 5 (day1@night)
# Room r3 is uncovered in shift 15 (day5@early)
# Room r3 is uncovered in shift 40 (day13@late)
# Room r4 is uncovered in shift 4 (day1@late)
# Room r4 is uncovered in shift 5 (day1@night)
# Room r1 is age-mixed 1/2 on day 4
# Room r1 is age-mixed 1/2 on day 5
# Room r1 is age-mixed 1/2 on day 6
# Room r1 is age-mixed 1/2 on day 7
# Room r2 is age-mixed 1/2 on day 2
# Room r2 is age-mixed 1/2 on day 3
# Room r2 is age-mixed 1/2 on day 7
# Room r2 is age-mixed 1/2 on day 8
# Room r2 is age-mixed 1/2 on day 11
# Room r2 is age-mixed 1/2 on day 12
# Room r2 is age-mixed 1/2 on day 13
# Nurse n01 is underqualified for patient p07 in room r0 in shift 4 (day1@late)
# Nurse n10 is underqualified for patient p05 in room r0 in shift 7 (day2@late)
# Nurse n06 is underqualified for patient p07 in room r0 in shift 10 (day3@late)
# Nurse n05 is underqualified for patient p34 in room r0 in shift 16 (day5@late)
# Nurse n12 is underqualified for patient p11 in room r0 in shift 22 (day7@late)
# Nurse n02 is underqualified for patient p11 in room r0 in shift 27 (day9@early)
# Nurse n02 is underqualified for patient p30 in room r0 in shift 30 (day10@early)
# Nurse n00 is underqualified for patient p17 in room r0 in shift 33 (day11@early)
# Nurse n00 is underqualified for patient p26 in room r0 in shift 33 (day11@early)
# Nurse n00 is underqualified for patient p30 in room r0 in shift 33 (day11@early)
# Nurse  is underqualified for patient p26 in room r0 in shift 40 (day13@late)
# Nurse  is underqualified for patient p33 in room r0 in shift 40 (day13@late)
# Nurse n02 is underqualified for patient p17 in room r0 in shift 41 (day13@night)
# Nurse n04 is underqualified for occupant a0 in room r1 in shift 0 (day0@early)
# Nurse n05 is underqualified for occupant a1 in room r1 in shift 8 (day2@night)
# Nurse n05 is underqualified for patient p10 in room r1 in shift 8 (day2@night)
# Nurse n07 is underqualified for occupant a0 in room r1 in shift 9 (day3@early)
# Nurse n06 is underqualified for occupant a1 in room r1 in shift 10 (day3@late)
# Nurse n02 is underqualified for occupant a0 in room r1 in shift 13 (day4@late)
# Nurse  is underqualified for occupant a0 in room r1 in shift 14 (day4@night)
# Nurse  is underqualified for patient p10 in room r1 in shift 14 (day4@night)
# Nurse n00 is underqualified for occupant a0 in room r1 in shift 16 (day5@late)
# Nurse n00 is underqualified for occupant a1 in room r1 in shift 16 (day5@late)
# Nurse n00 is underqualified for patient p10 in room r1 in shift 16 (day5@late)
# Nurse n05 is underqualified for occupant a1 in room r1 in shift 19 (day6@late)
# Nurse n05 is underqualified for patient p10 in room r1 in shift 19 (day6@late)
# Nurse n05 is underqualified for patient p35 in room r1 in shift 19 (day6@late)
# Nurse n07 is underqualified for patient p10 in room r1 in shift 21 (day7@early)
# Nurse n12 is underqualified for occupant a1 in room r1 in shift 22 (day7@late)
# Nurse n12 is underqualified for patient p10 in room r1 in shift 22 (day7@late)
# Nurse  is underqualified for occupant a4 in room r2 in shift 0 (day0@early)
# Nurse n10 is underqualified for patient p01 in room r2 in shift 3 (day1@early)
# Nurse n10 is underqualified for patient p01 in room r2 in shift 7 (day2@late)
# Nurse n06 is underqualified for patient p14 in room r2 in shift 10 (day3@late)
# Nurse n06 is underqualified for patient p21 in room r2 in shift 10 (day3@late)
# Nurse n05 is underqualified for patient p14 in room r2 in shift 13 (day4@late)
# Nurse n05 is underqualified for patient p20 in room r2 in shift 13 (day4@late)
# Nurse n00 is underqualified for patient p36 in room r2 in shift 16 (day5@late)
# Nurse n10 is underqualified for patient p14 in room r2 in shift 18 (day6@early)
# Nurse n05 is underqualified for patient p36 in room r2 in shift 19 (day6@late)
# Nurse n12 is underqualified for patient p14 in room r2 in shift 22 (day7@late)
# Nurse n12 is underqualified for patient p28 in room r2 in shift 22 (day7@late)
# Nurse n12 is underqualified for patient p36 in room r2 in shift 22 (day7@late)
# Nurse n05 is underqualified for patient p14 in room r2 in shift 25 (day8@late)
# Nurse n05 is underqualified for patient p28 in room r2 in shift 28 (day9@late)
# Nurse n07 is underqualified for patient p06 in room r2 in shift 31 (day10@late)
# Nurse n00 is underqualified for patient p19 in room r2 in shift 33 (day11@early)
# Nurse n10 is underqualified for patient p23 in room r2 in shift 34 (day11@late)
# Nurse  is underqualified for patient p13 in room r2 in shift 35 (day11@night)
# Nurse n04 is underqualified for patient p19 in room r2 in shift 40 (day13@late)
# Nurse n05 is underqualified for patient p19 in room r2 in shift 41 (day13@night)
# Nurse n05 is underqualified for patient p23 in room r2 in shift 41 (day13@night)
# Nurse n06 is underqualified for patient p02 in room r3 in shift 4 (day1@late)
# Nurse n02 is underqualified for patient p02 in room r3 in shift 6 (day2@early)
# Nurse n12 is underqualified for patient p02 in room r3 in shift 9 (day3@early)
# Nurse n04 is underqualified for patient p02 in room r3 in shift 13 (day4@late)
# Nurse  is underqualified for patient p00 in room r3 in shift 15 (day5@early)
# Nurse  is underqualified for patient p02 in room r3 in shift 15 (day5@early)
# Nurse n10 is underqualified for patient p00 in room r3 in shift 18 (day6@early)
# Nurse n12 is underqualified for patient p31 in room r3 in shift 22 (day7@late)
# Nurse n05 is underqualified for patient p00 in room r3 in shift 25 (day8@late)
# Nurse n05 is underqualified for patient p31 in room r3 in shift 25 (day8@late)
# Nurse n07 is underqualified for patient p00 in room r3 in shift 27 (day9@early)
# Nurse n07 is underqualified for patient p31 in room r3 in shift 27 (day9@early)
# Nurse n00 is underqualified for patient p00 in room r3 in shift 30 (day10@early)
# Nurse n10 is underqualified for patient p27 in room r3 in shift 34 (day11@late)
# Nurse  is underqualified for patient p27 in room r3 in shift 40 (day13@late)
# Nurse n02 is underqualified for patient p27 in room r3 in shift 41 (day13@night)
# Nurse n04 is underqualified for occupant a3 in room r4 in shift 0 (day0@early)
# Nurse n05 is underqualified for occupant a3 in room r4 in shift 1 (day0@late)
# Nurse  is underqualified for occupant a3 in room r4 in shift 4 (day1@late)
# Nurse  is underqualified for occupant a6 in room r4 in shift 4 (day1@late)
# Nurse  is underqualified for occupant a7 in room r4 in shift 4 (day1@late)
# Nurse  is underqualified for occupant a7 in room r4 in shift 5 (day1@night)
# Nurse n04 is underqualified for occupant a3 in room r4 in shift 6 (day2@early)
# Nurse n07 is underqualified for patient p16 in room r4 in shift 9 (day3@early)
# Nurse n06 is underqualified for patient p16 in room r4 in shift 10 (day3@late)
# Nurse n05 is underqualified for patient p16 in room r4 in shift 13 (day4@late)
# Nurse n00 is underqualified for patient p16 in room r4 in shift 16 (day5@late)
# Nurse n05 is underqualified for patient p16 in room r4 in shift 19 (day6@late)
# Nurse n12 is underqualified for patient p15 in room r4 in shift 22 (day7@late)
# Nurse n12 is underqualified for patient p16 in room r4 in shift 22 (day7@late)
# Nurse n12 is underqualified for patient p22 in room r4 in shift 22 (day7@late)
# Nurse n02 is underqualified for patient p15 in room r4 in shift 24 (day8@early)
# Nurse n02 is underqualified for patient p22 in room r4 in shift 24 (day8@early)
# Nurse n05 is underqualified for patient p15 in room r4 in shift 25 (day8@late)
# Nurse n05 is underqualified for patient p16 in room r4 in shift 25 (day8@late)
# Nurse n05 is underqualified for patient p22 in room r4 in shift 25 (day8@late)
# Nurse n02 is underqualified for patient p15 in room r4 in shift 27 (day9@early)
# Nurse n05 is underqualified for patient p15 in room r4 in shift 28 (day9@late)
# Nurse n07 is underqualified for patient p03 in room r4 in shift 31 (day10@late)
# Nurse n02 is underqualified for patient p03 in room r4 in shift 33 (day11@early)
# Nurse n02 is underqualified for patient p24 in room r4 in shift 33 (day11@early)
# Nurse n04 is underqualified for patient p29 in room r4 in shift 40 (day13@late)
# 11 distinct nurses for occupant a0
# 12 distinct nurses for occupant a1
# 3 distinct nurses for occupant a2
# 5 distinct nurses for occupant a3
# 5 distinct nurses for occupant a4
# 3 distinct nurses for occupant a5
# 5 distinct nurses for occupant a6
# 4 distinct nurses for occupant a7
# 11 distinct nurses for patient p00
# 5 distinct nurses for patient p01
# 11 distinct nurses for patient p02
# 8 distinct nurses for patient p03
# 6 distinct nurses for patient p05
# 5 distinct nurses for patient p06
# 7 distinct nurses for patient p07
# 3 distinct nurses for patient p08
# 6 distinct nurses for patient p09
# 11 distinct nurses for patient p10
# 8 distinct nurses for patient p11
# 8 distinct nurses for patient p12
# 6 distinct nurses for patient p13
# 12 distinct nurses for patient p14
# 7 distinct nurses for patient p15
# 10 distinct nurses for patient p16
# 7 distinct nurses for patient p17
# 6 distinct nurses for patient p18
# 6 distinct nurses for patient p19
# 6 distinct nurses for patient p20
# 6 distinct nurses for patient p21
# 10 distinct nurses for patient p22
# 6 distinct nurses for patient p23
# 8 distinct nurses for patient p24
# 2 distinct nurses for patient p25
# 7 distinct nurses for patient p26
# 8 distinct nurses for patient p27
# 7 distinct nurses for patient p28
# 3 distinct nurses for patient p29
# 5 distinct nurses for patient p30
# 7 distinct nurses for patient p31
# 2 distinct nurses for patient p33
# 10 distinct nurses for patient p34
# 9 distinct nurses for patient p35
# 11 distinct nurses for patient p36
# Excessive workload  11 for nurse n00 in shift 7 (day2@late)
# Excessive workload  12 for nurse n00 in shift 10 (day3@late)
# Excessive workload  14 for nurse n00 in shift 16 (day5@late)
# Excessive workload  9 for nurse n00 in shift 19 (day6@late)
# Excessive workload  9 for nurse n00 in shift 33 (day11@early)
# Excessive workload  11 for nurse n00 in shift 37 (day12@late)
# Excessive workload  2 for nurse n01 in shift 1 (day0@late)
# Excessive workload  3 for nurse n01 in shift 4 (day1@late)
# Excessive workload  11 for nurse n01 in shift 18 (day6@early)
# Excessive workload  11 for nurse n01 in shift 22 (day7@late)
# Excessive workload  2 for nurse n01 in shift 39 (day13@early)
# Excessive workload  16 for nurse n02 in shift 6 (day2@early)
# Excessive workload  27 for nurse n02 in shift 9 (day3@early)
# Excessive workload  22 for nurse n02 in shift 13 (day4@late)
# Excessive workload  7 for nurse n02 in shift 20 (day6@night)
# Excessive workload  4 for nurse n02 in shift 24 (day8@early)
# Excessive workload  9 for nurse n03 in shift 1 (day0@late)
# Excessive workload  7 for nurse n03 in shift 15 (day5@early)
# Excessive workload  11 for nurse n04 in shift 6 (day2@early)
# Excessive workload  4 for nurse n04 in shift 13 (day4@late)
# Excessive workload  11 for nurse n04 in shift 18 (day6@early)
# Excessive workload  1 for nurse n04 in shift 36 (day12@early)
# Excessive workload  4 for nurse n04 in shift 40 (day13@late)
# Excessive workload  3 for nurse n05 in shift 8 (day2@night)
# Excessive workload  2 for nurse n05 in shift 13 (day4@late)
# Excessive workload  5 for nurse n05 in shift 19 (day6@late)
# Excessive workload  12 for nurse n05 in shift 22 (day7@late)
# Excessive workload  8 for nurse n05 in shift 25 (day8@late)
# Excessive workload  2 for nurse n05 in shift 31 (day10@late)
# Excessive workload  20 for nurse n06 in shift 10 (day3@late)
# Excessive workload  5 for nurse n06 in shift 20 (day6@night)
# Excessive workload  25 for nurse n07 in shift 9 (day3@early)
# Excessive workload  24 for nurse n07 in shift 12 (day4@early)
# Excessive workload  4 for nurse n07 in shift 17 (day5@night)
# Excessive workload  14 for nurse n07 in shift 21 (day7@early)
# Excessive workload  5 for nurse n07 in shift 34 (day11@late)
# Excessive workload  2 for nurse n08 in shift 2 (day0@night)
# Excessive workload  5 for nurse n08 in shift 23 (day7@night)
# Excessive workload  7 for nurse n09 in shift 3 (day1@early)
# Excessive workload  21 for nurse n09 in shift 12 (day4@early)
# Excessive workload  18 for nurse n09 in shift 18 (day6@early)
# Excessive workload  2 for nurse n09 in shift 29 (day9@night)
# Excessive workload  8 for nurse n09 in shift 34 (day11@late)
# Excessive workload  7 for nurse n09 in shift 39 (day13@early)
# Excessive workload  7 for nurse n10 in shift 7 (day2@late)
# Excessive workload  7 for nurse n10 in shift 21 (day7@early)
# Excessive workload  9 for nurse n10 in shift 34 (day11@late)
# Excessive workload  8 for nurse n11 in shift 21 (day7@early)
# Excessive workload  18 for nurse n12 in shift 22 (day7@late)
# Operating theater t0 is open on day 1
# Operating theater t0 is open on day 2
# Operating theater t0 is open on day 3
# Operating theater t0 is open on day 4
# Operating theater t0 is open on day 7
# Operating theater t0 is open on day 10
# Operating theater t0 is open on day 11
# Operating theater t0 is open on day 13
# Operating theater t1 is open on day 1
# Operating theater t1 is open on day 2
# Operating theater t1 is open on day 3
# Operating theater t1 is open on day 7
# Operating theater t1 is open on day 10
# Operating theater t1 is open on day 11
# Surgeon s0 operates in 2 distinct operating theaters
# Surgeon s0 operates in 2 distinct operating theaters
# Surgeon s0 operates in 2 distinct operating theaters
# Surgeon s0 operates in 2 distinct operating theaters
# Surgeon s0 operates in 2 distinct operating theaters
# Surgeon s0 operates in 2 distinct operating theaters
# Patient p03 has been delayed for 7 days
# Patient p06 has been delayed for 9 days
# Patient p08 has been delayed for 11 days
# Patient p13 has been delayed for 8 days
# Patient p15 has been delayed for 6 days
# Patient p17 has been delayed for 4 days
# Patient p18 has been delayed for 9 days
# Patient p19 has been delayed for 10 days
# Patient p22 has been delayed for 3 days
# Patient p23 has been delayed for 9 days
# Patient p24 has been delayed for 9 days
# Patient p25 has been delayed for 12 days
# Patient p26 has been delayed for 1 days
# Patient p27 has been delayed for 10 days
# Patient p29 has been delayed for 12 days
# Patient p30 has been delayed for 8 days
# Patient p31 has been delayed for 5 days
# Patient p33 has been delayed for 12 days
# Patient p35 has been delayed for 1 days
# Patient p36 has been delayed for 2 days
# Elective patient p04 is unscheduled
# Elective patient p32 is unscheduled
# VIOLATIONS:
# RoomGenderMix.....................8
# PatientRoomCompatibility..........4
# SurgeonOvertime...................0
# OperatingTheaterOvertime..........0
# MandatoryUnscheduledPatients......0
# AdmissionDay......................0
# RoomCapacity.....................12
# NursePresence.....................0
# UncoveredRoom....................13
# Total violations = 37
#
# COSTS (weight X cost):
# RoomAgeMix............................55 (  5 X  11)
# RoomSkillLevel.......................560 (  5 X 112)
# ContinuityOfCare.....................298 (  1 X 298)
# ExcessiveNurseWorkload..............4660 ( 10 X 466)
# OpenOperatingTheater.................420 ( 30 X  14)
# SurgeonTransfer.......................60 ( 10 X   6)
# PatientDelay.........................740 (  5 X 148)
# ElectiveUnscheduledPatients..........300 (150 X   2)
# Total cost = 7093

# %%
def plot_cost_reduction(costs):
    plt.figure(figsize=(10, 6))
    plt.plot(costs, marker='o', label="Cost")
    plt.title("Cost Reduction Over Iterations")
    plt.xlabel("Iteration")
    plt.ylabel("Cost")
    plt.grid()
    plt.legend()
    plt.show()

plot_cost_reduction(cost_history)

# %%
def plot_violations(violations):
    keys = list(violations.keys())
    values = list(violations.values())

    plt.figure(figsize=(10, 6))
    plt.bar(keys, values, color='skyblue')
    plt.title("Breakdown of Validator Violations")
    plt.xlabel("Constraint Type")
    plt.ylabel("Violation Count")
    plt.xticks(rotation=45, ha="right")
    plt.grid(axis='y')
    plt.show()

plot_violations(violations)
