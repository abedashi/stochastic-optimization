# %%
import os
import time
import subprocess
import pandas as pd
import matplotlib.pyplot as plt

from algorithms.utils import read_input, write_solution
from algorithms.tabu_search import tabu_search, calculate_cost

# %%
# Paths
input_file = "data/instances/i01.json"
output_file = "data/output_solutions/out_sol_test01.json"
log_file = "./performance_log.csv"

# Ensure output folder exists
os.makedirs("./data/output_solutions", exist_ok=True)

# Initialize performance log
performance_log = []

# Step 1: Load Input Data
print(f"Processing {input_file}...")
data = read_input(input_file)

# Step 2: Run Tabu Search
start_time = time.time()
best_solution, cost_history = tabu_search(data, iterations=30, tabu_tenure=10)
end_time = time.time()

# Step 3: Calculate Final Cost
final_cost = calculate_cost(best_solution, data)

# Step 4: Save Solution
write_solution(output_file, best_solution)

# Step 5: Log Performance
performance_log.append({
    "instance": os.path.basename(input_file),
    "final_cost": final_cost,
    "execution_time": round(end_time - start_time, 2)
})

# Save log to CSV
df_log = pd.DataFrame(performance_log)
if os.path.exists(log_file):
    df_log.to_csv(log_file, mode='a', index=False, header=False)
else:
    df_log.to_csv(log_file, index=False, header=True)

print(f"Completed {input_file}: Cost = {final_cost}, Time = {round(end_time - start_time, 2)}s")
print(f"Solution saved to: {output_file}\n")

# Step 6: Run Validator Command
print("Running Validator...")
violations = {}
costs = {}
try:
    result = subprocess.run(
        ["./IHTP_Validator", input_file, output_file, "verbose"],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        check=True
    )
    print("Validator Output:")
    print(result.stdout)

    # Parse violations from validator output
    parsing_costs = False  # Track whether we are parsing the COSTS section
    for line in result.stdout.splitlines():
        if "VIOLATIONS:" in line:
            continue  # Skip the heading for violations
        if "COSTS" in line:
            parsing_costs = True  # Start parsing costs
            continue
        if "Total violations" in line or "Total cost" in line:
            continue  # Skip total lines
        if "...." in line and not parsing_costs:  # Parse violations
            parts = line.split("....", maxsplit=1)  # Split at the first set of dots
            if len(parts) == 2:
                key = parts[0].strip()  # Extract the violation name
                value_part = parts[1].strip()  # Extract the value part
                try:
                    # Extract only digits from the value
                    value = int(''.join(filter(str.isdigit, value_part)))
                    violations[key] = value
                except ValueError:
                    print(f"Warning: Could not parse value for {key} -> {value_part}")
        elif parsing_costs and "..." in line:  # Parse costs
            parts = line.split("...", maxsplit=1)  # Split at the first set of dots
            if len(parts) == 2:
                key = parts[0].strip()  # Extract the cost name
                value_part = parts[1].strip()  # Extract the value part
                try:
                    # Extract only digits from the value
                    value = int(''.join(filter(str.isdigit, value_part.split("(")[0])))
                    costs[key] = value
                except ValueError:
                    print(f"Warning: Could not parse value for {key} -> {value_part}")


except subprocess.CalledProcessError as e:
    print("Error running validator:")
    print(e.stderr)
# Out:
# Processing data/instances/i01.json...
# Iteration 0: Cost = 6936237
# Iteration 1: Cost = 5432327
# Iteration 2: Cost = 3930383
# Iteration 3: Cost = 2732434
# Iteration 4: Cost = 1826374
# Iteration 5: Cost = 930424
# Iteration 6: Cost = 330463
# Iteration 7: Cost = 325463
# Iteration 8: Cost = 321463
# Iteration 9: Cost = 318477
# Iteration 10: Cost = 318439
# Iteration 11: Cost = 318401
# Iteration 12: Cost = 318363
# Iteration 13: Cost = 318325
# Iteration 14: Cost = 318287
# Iteration 15: Cost = 318249
# Iteration 16: Cost = 318211
# Iteration 17: Cost = 318174
# Iteration 18: Cost = 318138
# Iteration 19: Cost = 318102
# Iteration 20: Cost = 318066
# Iteration 21: Cost = 318030
# Iteration 22: Cost = 317994
# Iteration 23: Cost = 317964
# Iteration 24: Cost = 317934
# Iteration 25: Cost = 317904
# Iteration 26: Cost = 317874
# Iteration 27: Cost = 317844
# Iteration 28: Cost = 317814
# Iteration 29: Cost = 317784
# Completed data/instances/i01.json: Cost = 317784, Time = 256.23s
# Solution saved to: data/output_solutions/out_sol_test01.json
#
# Running Validator...
# Validator Output:
# Room r0 is gender-mixed 1/2 on day 10
# Room r3 is gender-mixed 1/1 on day 8
# Room r0 is incompatible with patient p01
# Room r3 is incompatible with patient p14
# Surgeon s0 has 60 minutes of overtime on day 8
# Operating theaters t0 has 480 minutes of overtime on day 10
# Room r1 is overloaded by 1 on day 10
# Room r2 is overloaded by 1 on day 7
# Room r2 is overloaded by 2 on day 9
# Room r2 is overloaded by 2 on day 10
# Room r2 is overloaded by 2 on day 11
# Room r2 is overloaded by 1 on day 12
# Room r2 is uncovered in shift 14 (day4@night)
# Room r3 is uncovered in shift 17 (day5@night)
# Room r3 is uncovered in shift 23 (day7@night)
# Room r1 is age-mixed 1/2 on day 7
# Room r1 is age-mixed 1/2 on day 8
# Room r1 is age-mixed 1/2 on day 9
# Room r1 is age-mixed 1/2 on day 10
# Room r2 is age-mixed 1/2 on day 4
# Room r2 is age-mixed 1/2 on day 5
# Room r2 is age-mixed 1/2 on day 6
# Room r2 is age-mixed 1/2 on day 7
# Nurse n05 is underqualified for occupant a1 in room r0 in shift 0 (day0@early)
# Nurse n01 is underqualified for occupant a1 in room r0 in shift 1 (day0@late)
# Nurse n07 is underqualified for patient p00 in room r0 in shift 12 (day4@early)
# Nurse n02 is underqualified for patient p00 in room r0 in shift 13 (day4@late)
# Nurse n05 is underqualified for patient p00 in room r0 in shift 14 (day4@night)
# Nurse n03 is underqualified for patient p00 in room r0 in shift 15 (day5@early)
# Nurse n07 is underqualified for patient p00 in room r0 in shift 19 (day6@late)
# Nurse n03 is underqualified for patient p00 in room r0 in shift 21 (day7@early)
# Nurse n07 is underqualified for patient p00 in room r0 in shift 22 (day7@late)
# Nurse n05 is underqualified for patient p00 in room r0 in shift 23 (day7@night)
# Nurse n02 is underqualified for patient p00 in room r0 in shift 30 (day10@early)
# Nurse n02 is underqualified for patient p01 in room r0 in shift 30 (day10@early)
# Nurse n02 is underqualified for patient p22 in room r0 in shift 30 (day10@early)
# Nurse n07 is underqualified for patient p00 in room r0 in shift 31 (day10@late)
# Nurse n07 is underqualified for patient p01 in room r0 in shift 31 (day10@late)
# Nurse n05 is underqualified for patient p01 in room r0 in shift 33 (day11@early)
# Nurse n07 is underqualified for patient p02 in room r0 in shift 36 (day12@early)
# Nurse n07 is underqualified for patient p22 in room r0 in shift 36 (day12@early)
# Nurse n02 is underqualified for patient p01 in room r0 in shift 39 (day13@early)
# Nurse n02 is underqualified for patient p02 in room r0 in shift 39 (day13@early)
# Nurse n07 is underqualified for patient p01 in room r0 in shift 40 (day13@late)
# Nurse n07 is underqualified for patient p02 in room r0 in shift 40 (day13@late)
# Nurse n05 is underqualified for patient p04 in room r1 in shift 7 (day2@late)
# Nurse n07 is underqualified for patient p04 in room r1 in shift 19 (day6@late)
# Nurse n03 is underqualified for patient p03 in room r1 in shift 30 (day10@early)
# Nurse n02 is underqualified for patient p07 in room r1 in shift 33 (day11@early)
# Nurse n02 is underqualified for patient p10 in room r1 in shift 33 (day11@early)
# Nurse n05 is underqualified for patient p10 in room r1 in shift 36 (day12@early)
# Nurse n01 is underqualified for patient p06 in room r2 in shift 6 (day2@early)
# Nurse n05 is underqualified for patient p06 in room r2 in shift 7 (day2@late)
# Nurse n05 is underqualified for patient p06 in room r2 in shift 10 (day3@late)
# Nurse n07 is underqualified for patient p06 in room r2 in shift 12 (day4@early)
# Nurse n07 is underqualified for patient p09 in room r2 in shift 12 (day4@early)
# Nurse  is underqualified for patient p06 in room r2 in shift 14 (day4@night)
# Nurse n03 is underqualified for patient p06 in room r2 in shift 15 (day5@early)
# Nurse n03 is underqualified for patient p09 in room r2 in shift 15 (day5@early)
# Nurse n02 is underqualified for patient p06 in room r2 in shift 16 (day5@late)
# Nurse n02 is underqualified for patient p09 in room r2 in shift 16 (day5@late)
# Nurse n05 is underqualified for patient p06 in room r2 in shift 19 (day6@late)
# Nurse n03 is underqualified for patient p05 in room r2 in shift 26 (day8@night)
# Nurse n03 is underqualified for patient p12 in room r2 in shift 26 (day8@night)
# Nurse n02 is underqualified for patient p17 in room r2 in shift 27 (day9@early)
# Nurse n06 is underqualified for patient p17 in room r2 in shift 30 (day10@early)
# Nurse n03 is underqualified for patient p05 in room r2 in shift 33 (day11@early)
# Nurse n03 is underqualified for patient p12 in room r2 in shift 33 (day11@early)
# Nurse n03 is underqualified for patient p17 in room r2 in shift 33 (day11@early)
# Nurse n03 is underqualified for patient p19 in room r2 in shift 33 (day11@early)
# Nurse n06 is underqualified for patient p12 in room r2 in shift 34 (day11@late)
# Nurse n06 is underqualified for patient p19 in room r2 in shift 34 (day11@late)
# Nurse n05 is underqualified for patient p05 in room r2 in shift 36 (day12@early)
# Nurse n05 is underqualified for patient p12 in room r2 in shift 36 (day12@early)
# Nurse n05 is underqualified for patient p17 in room r2 in shift 36 (day12@early)
# Nurse n02 is underqualified for patient p05 in room r2 in shift 39 (day13@early)
# Nurse n02 is underqualified for patient p12 in room r2 in shift 39 (day13@early)
# Nurse n07 is underqualified for occupant a0 in room r3 in shift 0 (day0@early)
# Nurse n01 is underqualified for occupant a0 in room r3 in shift 1 (day0@late)
# Nurse n02 is underqualified for patient p08 in room r3 in shift 10 (day3@late)
# Nurse n03 is underqualified for patient p08 in room r3 in shift 15 (day5@early)
# Nurse n06 is underqualified for patient p08 in room r3 in shift 16 (day5@late)
# Nurse  is underqualified for patient p11 in room r3 in shift 17 (day5@night)
# Nurse n07 is underqualified for patient p08 in room r3 in shift 19 (day6@late)
# Nurse n07 is underqualified for patient p11 in room r3 in shift 19 (day6@late)
# Nurse n03 is underqualified for patient p14 in room r3 in shift 26 (day8@night)
# Nurse n07 is underqualified for patient p14 in room r3 in shift 27 (day9@early)
# Nurse n05 is underqualified for patient p15 in room r3 in shift 29 (day9@night)
# Nurse n02 is underqualified for patient p14 in room r3 in shift 30 (day10@early)
# Nurse n02 is underqualified for patient p15 in room r3 in shift 30 (day10@early)
# Nurse n03 is underqualified for patient p14 in room r3 in shift 33 (day11@early)
# Nurse n05 is underqualified for patient p15 in room r3 in shift 36 (day12@early)
# 3 distinct nurses for occupant a0
# 6 distinct nurses for occupant a1
# 6 distinct nurses for occupant a2
# 8 distinct nurses for patient p00
# 8 distinct nurses for patient p01
# 5 distinct nurses for patient p02
# 9 distinct nurses for patient p03
# 10 distinct nurses for patient p04
# 10 distinct nurses for patient p05
# 11 distinct nurses for patient p06
# 8 distinct nurses for patient p07
# 10 distinct nurses for patient p08
# 9 distinct nurses for patient p09
# 9 distinct nurses for patient p10
# 11 distinct nurses for patient p11
# 9 distinct nurses for patient p12
# 9 distinct nurses for patient p14
# 9 distinct nurses for patient p15
# 8 distinct nurses for patient p17
# 6 distinct nurses for patient p19
# 7 distinct nurses for patient p22
# Excessive workload  3 for nurse n00 in shift 24 (day8@early)
# Excessive workload  6 for nurse n00 in shift 28 (day9@late)
# Excessive workload  28 for nurse n00 in shift 31 (day10@late)
# Excessive workload  2 for nurse n00 in shift 34 (day11@late)
# Excessive workload  17 for nurse n00 in shift 37 (day12@late)
# Excessive workload  3 for nurse n01 in shift 25 (day8@late)
# Excessive workload  1 for nurse n01 in shift 28 (day9@late)
# Excessive workload  6 for nurse n02 in shift 10 (day3@late)
# Excessive workload  12 for nurse n02 in shift 16 (day5@late)
# Excessive workload  5 for nurse n02 in shift 22 (day7@late)
# Excessive workload  2 for nurse n02 in shift 27 (day9@early)
# Excessive workload  42 for nurse n02 in shift 30 (day10@early)
# Excessive workload  2 for nurse n02 in shift 33 (day11@early)
# Excessive workload  8 for nurse n03 in shift 15 (day5@early)
# Excessive workload  2 for nurse n03 in shift 18 (day6@early)
# Excessive workload  8 for nurse n03 in shift 30 (day10@early)
# Excessive workload  4 for nurse n03 in shift 33 (day11@early)
# Excessive workload  4 for nurse n04 in shift 29 (day9@night)
# Excessive workload  12 for nurse n04 in shift 32 (day10@night)
# Excessive workload  4 for nurse n05 in shift 23 (day7@night)
# Excessive workload  1 for nurse n05 in shift 36 (day12@early)
# Excessive workload  7 for nurse n06 in shift 34 (day11@late)
# Excessive workload  11 for nurse n08 in shift 21 (day7@early)
# Excessive workload  7 for nurse n08 in shift 24 (day8@early)
# Excessive workload  7 for nurse n08 in shift 37 (day12@late)
# Operating theater t0 is open on day 2
# Operating theater t0 is open on day 3
# Operating theater t0 is open on day 4
# Operating theater t0 is open on day 8
# Operating theater t0 is open on day 10
# Operating theater t1 is open on day 7
# Operating theater t1 is open on day 8
# Operating theater t1 is open on day 9
# Operating theater t1 is open on day 10
# Operating theater t1 is open on day 12
# Surgeon s0 operates in 2 distinct operating theaters
# Surgeon s0 operates in 2 distinct operating theaters
# Patient p01 has been delayed for 8 days
# Patient p02 has been delayed for 10 days
# Patient p03 has been delayed for 5 days
# Patient p05 has been delayed for 5 days
# Patient p09 has been delayed for 2 days
# Patient p10 has been delayed for 8 days
# Patient p11 has been delayed for 1 days
# Patient p12 has been delayed for 1 days
# Patient p14 has been delayed for 5 days
# Patient p15 has been delayed for 7 days
# Patient p17 has been delayed for 7 days
# Patient p19 has been delayed for 7 days
# Patient p22 has been delayed for 3 days
# Elective patient p13 is unscheduled
# Elective patient p16 is unscheduled
# Elective patient p18 is unscheduled
# Elective patient p20 is unscheduled
# Elective patient p21 is unscheduled
# Elective patient p23 is unscheduled
# Elective patient p24 is unscheduled
# Elective patient p25 is unscheduled
# Elective patient p26 is unscheduled
# Elective patient p27 is unscheduled
# VIOLATIONS:
# RoomGenderMix.....................2
# PatientRoomCompatibility..........2
# SurgeonOvertime..................60
# OperatingTheaterOvertime........480
# MandatoryUnscheduledPatients......0
# AdmissionDay......................0
# RoomCapacity......................9
# NursePresence.....................0
# UncoveredRoom.....................3
# Total violations = 556
#
# COSTS (weight X cost):
# RoomAgeMix............................40 (  5 X   8)
# RoomSkillLevel.......................960 ( 10 X  96)
# ContinuityOfCare.....................171 (  1 X 171)
# ExcessiveNurseWorkload..............2040 ( 10 X 204)
# OpenOperatingTheater.................300 ( 30 X  10)
# SurgeonTransfer.......................20 ( 10 X   2)
# PatientDelay.........................690 ( 10 X  69)
# ElectiveUnscheduledPatients.........3500 (350 X  10)
# Total cost = 7721

# %%
def plot_cost_reduction(costs):
    plt.figure(figsize=(10, 6))
    plt.plot(costs, marker='o', label="Cost")
    plt.title("Cost Reduction Over Iterations")
    plt.xlabel("Iteration")
    plt.ylabel("Cost")
    plt.grid()
    plt.legend()
    plt.show()

plot_cost_reduction(cost_history)

# %%
def plot_violations(violations):
    keys = list(violations.keys())
    values = list(violations.values())

    plt.figure(figsize=(10, 6))
    plt.bar(keys, values, color='skyblue')
    plt.title("Breakdown of Validator Violations")
    plt.xlabel("Constraint Type")
    plt.ylabel("Violation Count")
    plt.xticks(rotation=45, ha="right")
    plt.grid(axis='y')
    plt.show()

plot_violations(violations)
