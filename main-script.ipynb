# %%
import os
import time
import subprocess
import pandas as pd
import matplotlib.pyplot as plt

from algorithms.utils import read_input, write_solution
from algorithms.tabu_search import tabu_search, calculate_cost

# %%
# Paths
input_file = "data/instances/i01.json"
output_file = "data/output_solutions/out_sol_test01.json"
log_file = "./performance_log.csv"

# Ensure output folder exists
os.makedirs("./data/output_solutions", exist_ok=True)

# Initialize performance log
performance_log = []

# Step 1: Load Input Data
print(f"Processing {input_file}...")
data = read_input(input_file)

# Step 2: Run Tabu Search
start_time = time.time()
best_solution, cost_history = tabu_search(data, iterations=30, tabu_tenure=10)
end_time = time.time()

# Step 3: Calculate Final Cost
final_cost = calculate_cost(best_solution, data)

# Step 4: Save Solution
write_solution(output_file, best_solution)

# Step 5: Log Performance
performance_log.append({
    "instance": os.path.basename(input_file),
    "final_cost": final_cost,
    "execution_time": round(end_time - start_time, 2)
})

# Save log to CSV
df_log = pd.DataFrame(performance_log)
if os.path.exists(log_file):
    df_log.to_csv(log_file, mode='a', index=False, header=False)
else:
    df_log.to_csv(log_file, index=False, header=True)

print(f"Completed {input_file}: Cost = {final_cost}, Time = {round(end_time - start_time, 2)}s")
print(f"Solution saved to: {output_file}\n")

# Step 6: Run Validator Command
print("Running Validator...")
violations = {}
costs = {}
try:
    result = subprocess.run(
        ["./IHTP_Validator", input_file, output_file, "verbose"],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        check=True
    )
    print("Validator Output:")
    print(result.stdout)

    # Parse violations from validator output
    parsing_costs = False  # Track whether we are parsing the COSTS section
    for line in result.stdout.splitlines():
        if "VIOLATIONS:" in line:
            continue  # Skip the heading for violations
        if "COSTS" in line:
            parsing_costs = True  # Start parsing costs
            continue
        if "Total violations" in line or "Total cost" in line:
            continue  # Skip total lines
        if "...." in line and not parsing_costs:  # Parse violations
            parts = line.split("....", maxsplit=1)  # Split at the first set of dots
            if len(parts) == 2:
                key = parts[0].strip()  # Extract the violation name
                value_part = parts[1].strip()  # Extract the value part
                try:
                    # Extract only digits from the value
                    value = int(''.join(filter(str.isdigit, value_part)))
                    violations[key] = value
                except ValueError:
                    print(f"Warning: Could not parse value for {key} -> {value_part}")
        elif parsing_costs and "..." in line:  # Parse costs
            parts = line.split("...", maxsplit=1)  # Split at the first set of dots
            if len(parts) == 2:
                key = parts[0].strip()  # Extract the cost name
                value_part = parts[1].strip()  # Extract the value part
                try:
                    # Extract only digits from the value
                    value = int(''.join(filter(str.isdigit, value_part.split("(")[0])))
                    costs[key] = value
                except ValueError:
                    print(f"Warning: Could not parse value for {key} -> {value_part}")


except subprocess.CalledProcessError as e:
    print("Error running validator:")
    print(e.stderr)
# Out:
# Processing data/instances/i01.json...
# Iteration 0: Cost = 12617
# Iteration 1: Cost = 10471
# Iteration 2: Cost = 8351
# Iteration 3: Cost = 8312
# Iteration 4: Cost = 8312
# Iteration 5: Cost = 8312
# Iteration 6: Cost = 8312
# Iteration 7: Cost = 8312
# Iteration 8: Cost = 8312
# Iteration 9: Cost = 8312
# Iteration 10: Cost = 8312
# Iteration 11: Cost = 8312
# Iteration 12: Cost = 8312
# Iteration 13: Cost = 8312
# Iteration 14: Cost = 8312
# Iteration 15: Cost = 8312
# Iteration 16: Cost = 8312
# Iteration 17: Cost = 8312
# Iteration 18: Cost = 8312
# Iteration 19: Cost = 8312
# Iteration 20: Cost = 8312
# Iteration 21: Cost = 8312
# Iteration 22: Cost = 8312
# Iteration 23: Cost = 8312
# Iteration 24: Cost = 8312
# Iteration 25: Cost = 8312
# Iteration 26: Cost = 8312
# Iteration 27: Cost = 8312
# Iteration 28: Cost = 8312
# Iteration 29: Cost = 8312
# Completed data/instances/i01.json: Cost = 8312, Time = 11.99s
# Solution saved to: data/output_solutions/out_sol_test01.json
#
# Running Validator...
# Validator Output:
# Room r1 is gender-mixed 1/1 on day 8
# Room r1 is uncovered in shift 13 (day4@late)
# Room r1 is uncovered in shift 20 (day6@night)
# Room r1 is uncovered in shift 29 (day9@night)
# Nurse n07 is underqualified for occupant a1 in room r0 in shift 0 (day0@early)
# Nurse n01 is underqualified for occupant a1 in room r0 in shift 1 (day0@late)
# Nurse n03 is underqualified for occupant a2 in room r0 in shift 2 (day0@night)
# Nurse n02 is underqualified for occupant a1 in room r0 in shift 3 (day1@early)
# Nurse n02 is underqualified for occupant a2 in room r0 in shift 3 (day1@early)
# Nurse n01 is underqualified for patient p02 in room r0 in shift 6 (day2@early)
# Nurse n05 is underqualified for patient p05 in room r0 in shift 7 (day2@late)
# Nurse n02 is underqualified for patient p02 in room r0 in shift 10 (day3@late)
# Nurse n02 is underqualified for patient p05 in room r0 in shift 10 (day3@late)
# Nurse n03 is underqualified for patient p05 in room r0 in shift 11 (day3@night)
# Nurse n02 is underqualified for patient p05 in room r0 in shift 13 (day4@late)
# Nurse n02 is underqualified for patient p19 in room r0 in shift 13 (day4@late)
# Nurse n03 is underqualified for patient p05 in room r0 in shift 15 (day5@early)
# Nurse n03 is underqualified for patient p19 in room r0 in shift 15 (day5@early)
# Nurse n06 is underqualified for patient p19 in room r0 in shift 16 (day5@late)
# Nurse n07 is underqualified for patient p02 in room r0 in shift 19 (day6@late)
# Nurse n07 is underqualified for patient p05 in room r0 in shift 19 (day6@late)
# Nurse n06 is underqualified for patient p02 in room r0 in shift 21 (day7@early)
# Nurse n05 is underqualified for patient p02 in room r0 in shift 26 (day8@night)
# Nurse n05 is underqualified for patient p05 in room r0 in shift 26 (day8@night)
# Nurse  is underqualified for patient p11 in room r1 in shift 13 (day4@late)
# Nurse n07 is underqualified for patient p11 in room r1 in shift 19 (day6@late)
# Nurse  is underqualified for patient p11 in room r1 in shift 20 (day6@night)
# Nurse n07 is underqualified for patient p07 in room r1 in shift 27 (day9@early)
# Nurse n07 is underqualified for patient p07 in room r1 in shift 31 (day10@late)
# Nurse n02 is underqualified for patient p07 in room r1 in shift 33 (day11@early)
# Nurse n07 is underqualified for occupant a0 in room r3 in shift 0 (day0@early)
# Nurse n01 is underqualified for occupant a0 in room r3 in shift 1 (day0@late)
# 3 distinct nurses for occupant a0
# 6 distinct nurses for occupant a1
# 6 distinct nurses for occupant a2
# 11 distinct nurses for patient p02
# 11 distinct nurses for patient p05
# 9 distinct nurses for patient p07
# 10 distinct nurses for patient p11
# 7 distinct nurses for patient p19
# Excessive workload  5 for nurse n00 in shift 16 (day5@late)
# Operating theater t0 is open on day 2
# Operating theater t0 is open on day 3
# Operating theater t0 is open on day 8
# Patient p11 has been delayed for 1 days
# Patient p19 has been delayed for 1 days
# Elective patient p00 is unscheduled
# Elective patient p01 is unscheduled
# Elective patient p03 is unscheduled
# Elective patient p04 is unscheduled
# Elective patient p06 is unscheduled
# Elective patient p08 is unscheduled
# Elective patient p09 is unscheduled
# Elective patient p10 is unscheduled
# Elective patient p12 is unscheduled
# Elective patient p13 is unscheduled
# Elective patient p14 is unscheduled
# Elective patient p15 is unscheduled
# Elective patient p16 is unscheduled
# Elective patient p17 is unscheduled
# Elective patient p18 is unscheduled
# Elective patient p20 is unscheduled
# Elective patient p21 is unscheduled
# Elective patient p22 is unscheduled
# Elective patient p23 is unscheduled
# Elective patient p24 is unscheduled
# Elective patient p25 is unscheduled
# Elective patient p26 is unscheduled
# Elective patient p27 is unscheduled
# VIOLATIONS:
# RoomGenderMix.....................1
# PatientRoomCompatibility..........0
# SurgeonOvertime...................0
# OperatingTheaterOvertime..........0
# MandatoryUnscheduledPatients......0
# AdmissionDay......................0
# RoomCapacity......................0
# NursePresence.....................0
# UncoveredRoom.....................3
# Total violations = 4
#
# COSTS (weight X cost):
# RoomAgeMix.............................0 (  5 X   0)
# RoomSkillLevel.......................370 ( 10 X  37)
# ContinuityOfCare......................63 (  1 X  63)
# ExcessiveNurseWorkload................50 ( 10 X   5)
# OpenOperatingTheater..................90 ( 30 X   3)
# SurgeonTransfer........................0 ( 10 X   0)
# PatientDelay..........................20 ( 10 X   2)
# ElectiveUnscheduledPatients.........8050 (350 X  23)
# Total cost = 8643

# %%
def plot_cost_reduction(costs):
    plt.figure(figsize=(10, 6))
    plt.plot(costs, marker='o', label="Cost")
    plt.title("Cost Reduction Over Iterations")
    plt.xlabel("Iteration")
    plt.ylabel("Cost")
    plt.grid()
    plt.legend()
    plt.show()

plot_cost_reduction(cost_history)

# %%
def plot_violations(violations):
    keys = list(violations.keys())
    values = list(violations.values())

    plt.figure(figsize=(10, 6))
    plt.bar(keys, values, color='skyblue')
    plt.title("Breakdown of Validator Violations")
    plt.xlabel("Constraint Type")
    plt.ylabel("Violation Count")
    plt.xticks(rotation=45, ha="right")
    plt.grid(axis='y')
    plt.show()

plot_violations(violations)
